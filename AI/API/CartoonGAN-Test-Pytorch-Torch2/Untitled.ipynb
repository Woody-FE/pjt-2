# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\jjs\appdata\local\programs\python\python36\lib\site-packages (4.4.0.42)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\jjs\appdata\local\programs\python\python36\lib\site-packages (from opencv-python) (1.19.1)

# %%
import torch
import torchvision.transforms as transforms
import cv2
import matplotlib.pyplot as plt

from network.Transformer import Transformer

# %%
model = Transformer()
model.load_state_dict(torch.load('pretrained_model/Paprika_net_G_float.pth'))
model.eval()
print('Model Loaded!')
# Out:
# Model Loaded!

# %%
img_size = 450
img_path = 'test_img/kim.jpg'

img = cv2.imread(img_path)

T = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(img_size, 2),
    transforms.ToTensor()
])

img_input = T(img).unsqueeze(0)

img_input = -1 + 2 * img_input # 0 - 1 -> -1 - +1

plt.figure(figsize=(16,10))
plt.imshow(img[:,:,::-1])

# %%
img_output = model(img_input)

img_output = img_output.squeeze().detach().numpy() +1. / 2.
img_output = img_output.transpose([1, 2, 0])

plt.figure(figsize=(16,10))
plt.imshow(img_output[:,:,::-1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
